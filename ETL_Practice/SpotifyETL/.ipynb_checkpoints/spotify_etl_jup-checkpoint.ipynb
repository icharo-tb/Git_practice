# %%
import pandas as pd

# %% [markdown]
# ## JSON File
# - Working with the file I realized that creating a json file was giving better results in order to make an analysis
# - Although it was also loaded on a local MongoDB cluster it wasn´t showed as expected
# - Therefore, using a json string to generate the file and reading it with pandas to make the analysis is so much better
# - Still, PyMongo is useful to store that data on a NoSQL database and I should try with another DBs such as PostgresSQL or MySQL

# %%
df = pd.read_json('spotify_etl.json', 'r')
df
# Out:
# C:\Users\DANIEL\AppData\Local\Temp\ipykernel_3536\2288657148.py:1: FutureWarning: Starting with pandas version 2.0 all arguments of read_json except for the argument 'path_or_buf' will be keyword-only.
#   df = pd.read_json('spotify_etl.json', 'r')
#                           song_name   artist_name  \
# 0                           L’enfer       Stromae
# 1                      Pas vraiment       Stromae
# 2                            carmen       Stromae
# 3                      Fils de joie       Stromae
# 4                            bâtard       Stromae
# 5                             Santé       Stromae
# 6                              Riez       Stromae
# 7                     Bonne journée       Stromae
# 8                           Copines  Aya Nakamura
# 9                    Tous les mêmes       Stromae
# 10                 Mauvaise journée       Stromae
# 11                      Déclaration       Stromae
# 12                   La solassitude       Stromae
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_name    20 non-null     object
#  1   artist_name  20 non-null     object
#  2   played_at    20 non-null     datetime64[ns, UTC]
#  3   timestamp    20 non-null     datetime64[ns]
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), object(2)
# memory usage: 768.0+ bytes
